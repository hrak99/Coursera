# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %%
punctuation_chars = ["'", '"', ",", ".", "!", ":", ";", '#', '@']
positive_words = []
with open("/kaggle/input/vocabulary-and-twitter-data/positive_words.txt.txt") as pos_f:
    for lin in pos_f:
        if lin[0] != ';' and lin[0] != '\n':
            positive_words.append(lin.strip())
negative_words = []
with open("/kaggle/input/vocabulary-and-twitter-data/negative_words.txt.txt") as pos_f:
    for lin in pos_f:
        if lin[0] != ';' and lin[0] != '\n':
            negative_words.append(lin.strip())
#print (positive_words)
#print (negative_words)

#outfile = open ('resulting_data.csv','w')
tweets = []
temp_list = []
retweets_count = []
reply_count = []
pos_count = 0
neg_count = 0
pos = []
neg = []
net_score = []
#score = 0
with open('/kaggle/input/vocabulary-and-twitter-data/project_twitter_data.csv.txt','r') as twitter:
    first_line = twitter.readline()
        #temp_list = []
    for char in twitter:
        pos_count = 0
        char = char.replace ('#','')
        char = char.replace ('!','')
        char = char.replace (".",'')
        char = char.replace ("@",'')
        char = char.replace ('?','')
        char = char.replace (':','')
        char = char.replace (';','')
        char = char.replace ('-','')
        temp_list.append (char)
        final_str =''.join(temp_list)
        final_str = final_str.lower()
        #final_str = final_str.split()
        retweets_count.append(final_str[-4])
        reply_count.append(final_str[-2])
        final_str = final_str.split()
        #tweets.append(final_str[:-4])
        #tweets_str = ''.join(tweets)
        #tweets_str = tweets_str.lower()
        #tweets_str = tweets_str.split()
        for words in final_str:
            if words in positive_words:
                pos_count +=1
            elif words in negative_words:
                neg_count +=1
        #if pos_count >= neg_count:
            #score = 'Positive'
        #elif pos_count < neg_count:
        score = pos_count - neg_count
        pos.append(pos_count)
        neg.append(neg_count)
        net_score.append(score)

        temp_list = []

        #print (tweets)


        #for words in final_str1:
         #   if words in negative_words:
          #      neg_count += 1
        #elif words in positive_words:
         #   pos_count += 1
        #print(final_str)
        #last_word = final_str[-4]
        #for count in last_word:
            #print (count)

        #retweets_count.append(final_str[])
        #reply_count.append(final_str[])
        #print (final_str)
#print (tweets_str)
#print (final_str)
print (final_str)
print ("Number of Retweets",retweets_count)
print ('Number of Replies',reply_count)
print ('Positive Score',pos)
print ('Negative Score',neg)
print ('Net_score',net_score)
#k = []
data_list = []
for a,b,c,d,e in zip(retweets_count,reply_count, pos, neg, net_score):
    data = (a,b,c,d,e)
    data_list.append(data)
print (data_list)
# Incerting data in csv fomat
outfile = open ('resulting_data.csv','w')
# headers
outfile.write ('Number of Retweets,Number of Replies,Positive Score,Negative Score,Net Score')
outfile.write('\n')
for temp_data  in data_list[:-1]:
    row_str = "{},{},{},{},{}".format (temp_data[0],temp_data[1],temp_data[2],\
                                       temp_data[3],temp_data[4])
    #[temp_list[0],temp_list[1],str(temp_list[2]),
                         #str(temp_list[3]),temp_list[4]])
    outfile.write (row_str)
    outfile.write ('\n')

    #print (z)

    #row_str = ''.join (z[0],z[1])#,str(z[2]),str(z[3]),z[4])
        #row_str = ','.join (k)


    #z = []
#print (z)
outfile.close()


#print (a,b,c)
#print (pos_count)
#print (neg_count)
# lists of words to use


        #print (len (line))
        #row_strings = ','.join ([str(line[-4]),str(line[-2])])
        #outfile = open ('resulting_data.csv','w')
        #outfile.write (row_strings)
        #outfile.write ('\n')
#outfile.close()

#with open ('resulting_data.csv','r') as fb:
 #   for lin in fb:
        #print (lin)
#print (final_str)




#outfile = open('resulting_data.csv','w')
# outfile headers
#outfile.write ('Number of Retweets', 'Number of Replies', 'Positive Score',\
#               'Negative Score')

# %%
df = pd.read_csv('resulting_data.csv')
df.tail()

# %%
#import seaborn as sns; 
#import matplotlib.pyplot as plt
#ax = sns.scatterplot( x='Net Score', y= 'Number of Retweets', data=df)

# %%
import matplotlib.pyplot as plt
df.plot(kind='scatter', x='Net Score', y='Number of Retweets', figsize=(10, 6), color='darkblue')
plt.grid(color='g', linestyle='-', linewidth=2)
plt.title('Net Score vs Retweets')
